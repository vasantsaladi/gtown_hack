# %%
import pandas as pd

census_tracts = pd.read_csv("csv/Census_Tracts_in_2020.csv")
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  P0010001  P0010002  P0010003  P0010004  \
# 0         1   2002  11001002002      4072      3647      1116      1751
# 1         2   2101  11001002101      5687      5071      1037      2642
# 2         3   2102  11001002102      5099      4599       901      2910
# 3         4   2201  11001002201      3485      3138       973      1722
# 4         5   2202  11001002202      3339      2957       619      1636
#
#    P0010005  P0010006  P0010007  ...  P0050003  P0050004  P0050005  P0050006  \
# 0        27        84         0  ...         0         0         0         0
# 1        86       120         1  ...         0         0         0         0
# 2        50        87         0  ...         0         0         0         0
# 3        21        94         2  ...         0         6         0         0
# 4        48        57         3  ...         0         0         0         0
#
#    P0050007  P0050008  P0050009  P0050010  SHAPEAREA  SHAPELEN
# ...

# %%
total_pop = census_tracts["P0010001"].sum()
print("Total pop: ", total_pop)
# Out:
# Total pop:  689545

# %%
census_tracts["pop_percent"] = census_tracts["P0010001"] / total_pop
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  P0010001  P0010002  P0010003  P0010004  \
# 0         1   2002  11001002002      4072      3647      1116      1751
# 1         2   2101  11001002101      5687      5071      1037      2642
# 2         3   2102  11001002102      5099      4599       901      2910
# 3         4   2201  11001002201      3485      3138       973      1722
# 4         5   2202  11001002202      3339      2957       619      1636
#
#    P0010005  P0010006  P0010007  ...  P0050004  P0050005  P0050006  P0050007  \
# 0        27        84         0  ...         0         0         0        32
# 1        86       120         1  ...         0         0         0        31
# 2        50        87         0  ...         0         0         0       145
# 3        21        94         2  ...         6         0         0         0
# 4        48        57         3  ...         0         0         0         4
#
#    P0050008  P0050009  P0050010  SHAPEAREA  SHAPELEN  pop_percent
# ...

# %%
# Get list of all columns
cols = census_tracts.columns.tolist()

# Remove pop_percent from its current position
cols.remove('pop_percent')

# Find the index of GEOID and insert pop_percent after it
geoid_index = cols.index('GEOID')
cols.insert(geoid_index + 1, 'pop_percent')

# Reorder the DataFrame columns
census_tracts = census_tracts.reindex(columns=cols)

# %%
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  pop_percent  P0010001  P0010002  P0010003  \
# 0         1   2002  11001002002     0.005905      4072      3647      1116
# 1         2   2101  11001002101     0.008247      5687      5071      1037
# 2         3   2102  11001002102     0.007395      5099      4599       901
# 3         4   2201  11001002201     0.005054      3485      3138       973
# 4         5   2202  11001002202     0.004842      3339      2957       619
#
#    P0010004  P0010005  P0010006  ...  P0050003  P0050004  P0050005  P0050006  \
# 0      1751        27        84  ...         0         0         0         0
# 1      2642        86       120  ...         0         0         0         0
# 2      2910        50        87  ...         0         0         0         0
# 3      1722        21        94  ...         0         6         0         0
# 4      1636        48        57  ...         0         0         0         0
#
# ...

# %%
census_tracts = census_tracts.rename(columns={'P0010001': 'total_pop'})
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  pop_percent  total_pop  P0010002  P0010003  \
# 0         1   2002  11001002002     0.005905       4072      3647      1116
# 1         2   2101  11001002101     0.008247       5687      5071      1037
# 2         3   2102  11001002102     0.007395       5099      4599       901
# 3         4   2201  11001002201     0.005054       3485      3138       973
# 4         5   2202  11001002202     0.004842       3339      2957       619
#
#    P0010004  P0010005  P0010006  ...  P0050003  P0050004  P0050005  P0050006  \
# 0      1751        27        84  ...         0         0         0         0
# 1      2642        86       120  ...         0         0         0         0
# 2      2910        50        87  ...         0         0         0         0
# 3      1722        21        94  ...         0         6         0         0
# 4      1636        48        57  ...         0         0         0         0
#
# ...

# %%
census_tracts.drop(["P0010002"], axis=1, inplace=True)

census_tracts = census_tracts.rename(columns={
    'P0010003': 'white',
    'P0010004': 'black',
    'P0010005': 'american_indian',
    'P0010006': 'asian',
    'P0010007': 'pacific_islander',
    'P0010008': 'other',
    'P0020002': 'hispanic'
})

census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  pop_percent  total_pop  white  black  \
# 0         1   2002  11001002002     0.005905       4072   1116   1751
# 1         2   2101  11001002101     0.008247       5687   1037   2642
# 2         3   2102  11001002102     0.007395       5099    901   2910
# 3         4   2201  11001002201     0.005054       3485    973   1722
# 4         5   2202  11001002202     0.004842       3339    619   1636
#
#    american_indian  asian  pacific_islander  ...  P0050003  P0050004  \
# 0               27     84                 0  ...         0         0
# 1               86    120                 1  ...         0         0
# 2               50     87                 0  ...         0         0
# 3               21     94                 2  ...         0         6
# 4               48     57                 3  ...         0         0
#
#    P0050005  P0050006  P0050007  P0050008  P0050009  P0050010  SHAPEAREA  \
# ...

# %%
print(list(census_tracts.columns))
# Out:
# ['OBJECTID', 'TRACT', 'GEOID', 'pop_percent', 'total_pop', 'white', 'black', 'american_indian', 'asian', 'pacific_islander', 'other', 'hispanic', 'P0020005', 'P0020006', 'P0020007', 'P0020008', 'P0020009', 'P0020010', 'P0030001', 'P0030003', 'P0030004', 'P0030005', 'P0030006', 'P0030007', 'P0030008', 'P0040002', 'P0040005', 'P0040006', 'P0040007', 'P0040008', 'P0040009', 'P0040010', 'H0010001', 'H0010002', 'H0010003', 'ALAND', 'AWATER', 'STUSAB', 'SUMLEV', 'GEOCODE', 'STATE', 'NAME', 'POP100', 'HU100', 'P0010009', 'P0010010', 'P0010011', 'P0010012', 'P0010013', 'P0010014', 'P0010015', 'P0010016', 'P0010017', 'P0010018', 'P0010019', 'P0010020', 'P0010021', 'P0010022', 'P0010023', 'P0010024', 'P0010025', 'P0010026', 'P0010027', 'P0010028', 'P0010029', 'P0010030', 'P0010031', 'P0010032', 'P0010033', 'P0010034', 'P0010035', 'P0010036', 'P0010037', 'P0010038', 'P0010039', 'P0010040', 'P0010041', 'P0010042', 'P0010043', 'P0010044', 'P0010045', 'P0010046', 'P0010047', 'P0010048', 'P0010049'
# ...

# %%
cols_to_drop = [col for col in census_tracts.columns if col.startswith('P00')]
census_tracts = census_tracts.drop(columns=cols_to_drop)
print(list(census_tracts.columns))
# Out:
# ['OBJECTID', 'TRACT', 'GEOID', 'pop_percent', 'total_pop', 'white', 'black', 'american_indian', 'asian', 'pacific_islander', 'other', 'hispanic', 'H0010001', 'H0010002', 'H0010003', 'ALAND', 'AWATER', 'STUSAB', 'SUMLEV', 'GEOCODE', 'STATE', 'NAME', 'POP100', 'HU100', 'SHAPEAREA', 'SHAPELEN']

# %%
census_tracts.drop(["H0010001", "H0010002", "H0010003", "POP100", "HU100"], axis=1, inplace=True)
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  pop_percent  total_pop  white  black  \
# 0         1   2002  11001002002     0.005905       4072   1116   1751
# 1         2   2101  11001002101     0.008247       5687   1037   2642
# 2         3   2102  11001002102     0.007395       5099    901   2910
# 3         4   2201  11001002201     0.005054       3485    973   1722
# 4         5   2202  11001002202     0.004842       3339    619   1636
#
#    american_indian  asian  pacific_islander  ...  hispanic   ALAND  AWATER  \
# 0               27     84                 0  ...      1022  849376       0
# 1               86    120                 1  ...      1868  600992       0
# 2               50     87                 0  ...      1074  725975       0
# 3               21     94                 2  ...       683  415173       0
# 4               48     57                 3  ...      1003  698895     566
#
#    STUSAB SUMLEV      GEOCODE  STATE                NAME SHAPEAREA  SHAPELEN
# ...

# %%
print(list(census_tracts.columns))
# Out:
# ['OBJECTID', 'TRACT', 'GEOID', 'pop_percent', 'total_pop', 'white', 'black', 'american_indian', 'asian', 'pacific_islander', 'other', 'hispanic', 'ALAND', 'AWATER', 'STUSAB', 'SUMLEV', 'GEOCODE', 'STATE', 'NAME', 'SHAPEAREA', 'SHAPELEN']

# %%
census_tracts["white_percent"] = census_tracts["white"] / census_tracts["total_pop"]
census_tracts["black_percent"] = census_tracts["black"] / census_tracts["total_pop"]
census_tracts["hispanic_percent"] = census_tracts["hispanic"] / census_tracts["total_pop"]
census_tracts["asian_percent"] = census_tracts["asian"] / census_tracts["total_pop"]
census_tracts["other_percent"] = census_tracts["other"] / census_tracts["total_pop"]
census_tracts["american_indian_percent"] = census_tracts["american_indian"] / census_tracts["total_pop"]
census_tracts["pacific_islander_percent"] = census_tracts["pacific_islander"] / census_tracts["total_pop"]
census_tracts.head()
# Out:
#    OBJECTID  TRACT        GEOID  pop_percent  total_pop  white  black  \
# 0         1   2002  11001002002     0.005905       4072   1116   1751
# 1         2   2101  11001002101     0.008247       5687   1037   2642
# 2         3   2102  11001002102     0.007395       5099    901   2910
# 3         4   2201  11001002201     0.005054       3485    973   1722
# 4         5   2202  11001002202     0.004842       3339    619   1636
#
#    american_indian  asian  pacific_islander  ...                NAME  \
# 0               27     84                 0  ...  Census Tract 20.02
# 1               86    120                 1  ...  Census Tract 21.01
# 2               50     87                 0  ...  Census Tract 21.02
# 3               21     94                 2  ...  Census Tract 22.01
# 4               48     57                 3  ...  Census Tract 22.02
#
#    SHAPEAREA  SHAPELEN  white_percent black_percent  hispanic_percent  \
# ...

# %%
# Export to CSV in the public/data folder
census_tracts.to_csv('../public/data/cleaned_census_tracts.csv', index=False)
